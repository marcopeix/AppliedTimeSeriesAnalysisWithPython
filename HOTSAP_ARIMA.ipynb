# %% [markdown]
# # ARIMA

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [10, 7.5]

# %% [markdown]
# ## Johnson&Johnson Quarterly Earnings per Share

# %%
data = pd.read_csv('jj.csv')
data.head()
# Out:
#          date  data
# 0  1960-01-01  0.71
# 1  1960-04-01  0.63
# 2  1960-07-02  0.85
# 3  1960-10-01  0.44
# 4  1961-01-01  0.61

# %%
plt.plot(data['date'], data['data'])
plt.title('Quarterly EPS for Johnson & Johnson')
plt.ylabel('EPS per share ($)')
plt.xlabel('Date')
plt.xticks(rotation=90)
plt.show()

# %%
plot_pacf(data['data']);
plot_acf(data['data']);

# %%
ad_fuller_result = adfuller(data['data'])

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: 2.7420165734574766
# p-value: 1.0

# %%
data['data_tr_1'] = np.log(data['data'])
data['data_tr_1'] = data['data_tr_1'].diff()

data.head(10)
# Out:
#          date  data  data_tr_1
# 0  1960-01-01  0.71        NaN
# 1  1960-04-01  0.63  -0.119545
# 2  1960-07-02  0.85   0.299517
# 3  1960-10-01  0.44  -0.658462
# 4  1961-01-01  0.61   0.326684
# 5  1961-04-02  0.69   0.123233
# 6  1961-07-02  0.92   0.287682
# 7  1961-10-01  0.55  -0.514455
# 8  1962-01-01  0.72   0.269333
# 9  1962-04-02  0.77   0.067139

# %%
plt.plot(data['data_tr_1'])
plt.title("Log Difference of Quarterly EPS for Johnson & Johnson")
plt.show()

# %%
ad_fuller_result = adfuller(data['data_tr_1'][1:])

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -4.317043945811839
# p-value: 0.000414973140444062

# %%
plot_pacf(data['data_tr_1'][1:]);
plot_acf(data['data_tr_1'][1:]);

# %%
def optimize_ARIMA(endog, order_list):
    """
        Return dataframe with parameters and corresponding AIC
        
        order_list - list with (p, d, q) tuples
        endog - the observed variable
    """
    
    results = []
    
    for order in tqdm_notebook(order_list):
        try: 
            model = SARIMAX(endog, order=order, simple_differencing=False).fit(disp=False)
        except:
            continue
            
        aic = model.aic
        results.append([order, model.aic])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p, d, q)', 'AIC']
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
ps = range(0, 8, 1)
d = 1
qs = range(0, 8, 1)

# Create a list with all possible combination of parameters
parameters = product(ps, qs)
parameters_list = list(parameters)

order_list = []

for each in parameters_list:
    each = list(each)
    each.insert(1, 1)
    each = tuple(each)
    order_list.append(each)
    
order_list[:10]
# Out:
# [(0, 1, 0),
#  (0, 1, 1),
#  (0, 1, 2),
#  (0, 1, 3),
#  (0, 1, 4),
#  (0, 1, 5),
#  (0, 1, 6),
#  (0, 1, 7),
#  (1, 1, 0),
#  (1, 1, 1)]

# %%
result_df = optimize_ARIMA(data['data'], order_list)
result_df
# Out:
# HBox(children=(IntProgress(value=0, max=64), HTML(value='')))
#     (p, d, q)         AIC
# 0   (6, 1, 3)  115.574372
# 1   (4, 1, 6)  115.859401
# 2   (7, 1, 1)  116.052682
# 3   (5, 1, 3)  116.534782
# 4   (5, 1, 2)  117.196836
# ..        ...         ...
# 59  (0, 1, 1)  265.481216
# 60  (0, 1, 3)  265.497398
# 61  (1, 1, 0)  266.632563
# 62  (2, 1, 0)  267.751437
# 63  (0, 1, 0)  295.995493
#
# [64 rows x 2 columns]

# %%
best_model = SARIMAX(data['data'], order=(6,1,3), simple_differencing=False)
res = best_model.fit(disp=False)
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   data   No. Observations:                   84
# Model:               SARIMAX(6, 1, 3)   Log Likelihood                 -47.787
# Date:                Sat, 24 Oct 2020   AIC                            115.574
# Time:                        16:49:58   BIC                            139.763
# Sample:                             0   HQIC                           125.292
#                                  - 84
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.4400      0.124    -11.606      0.000      -1.683      -1.197
# ar.L2         -0.7234      0.148     -4.877      0.000      -1.014      -0.433
# ar.L3          0.0486      0.063      0.769      0.442      -0.075       0.173
# ar.L4          1.0115      0.046     22.214      0.000       0.922       1.101
# ar.L5          1.3924      0.130     10.741      0.000       1.138       1.646
# ar.L6          0.6929      0.148      4.677      0.000       0.403       0.983
# ma.L1          0.6904      0.114      6.058      0.000       0.467       0.914
# ma.L2         -0.1756      0.105     -1.673      0.094      -0.381       0.030
# ma.L3         -0.7262      0.074     -9.763      0.000      -0.872      -0.580
# sigma2         0.1598      0.025      6.397      0.000       0.111       0.209
# ===================================================================================
# Ljung-Box (Q):                       31.67   Jarque-Bera (JB):                63.76
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):              39.39   Skew:                            -0.70
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
res.plot_diagnostics();

# %%
n_forecast = 8
predict = res.get_prediction(end=best_model.nobs + n_forecast)
idx = np.arange(len(predict.predicted_mean))

fig, ax = plt.subplots()
ax.plot(data['data'], 'blue')
ax.plot(idx[-n_forecast:], predict.predicted_mean[-n_forecast:], 'k--')

ax.set(title='Forecast of Johnson&Johnson Quarterly EPS')
plt.show()

# %%
data['model'] = predict.predicted_mean
data.head(15)
# Out:
#           date  data  data_tr_1     model
# 0   1960-01-01  0.71        NaN  0.000000
# 1   1960-04-01  0.63  -0.119545  0.709998
# 2   1960-07-02  0.85   0.299517  0.678566
# 3   1960-10-01  0.44  -0.658462  0.722026
# 4   1961-01-01  0.61   0.326684  0.649570
# 5   1961-04-02  0.69   0.123233  0.528291
# 6   1961-07-02  0.92   0.287682  0.787676
# 7   1961-10-01  0.55  -0.514455  0.493006
# 8   1962-01-01  0.72   0.269333  0.646793
# 9   1962-04-02  0.77   0.067139  0.752807
# 10  1962-07-02  0.92   0.177983  0.986372
# 11  1962-10-01  0.60  -0.427444  0.587558
# 12  1963-01-01  0.83   0.324496  0.780728
# 13  1963-04-02  0.80  -0.036814  0.839440
# 14  1963-07-02  1.00   0.223144  0.957472

# %%
mse = mean_squared_error(data['data'], data['model'])
print(f'MSE: {mse}')
# Out:
# MSE: 0.16237821078357895
